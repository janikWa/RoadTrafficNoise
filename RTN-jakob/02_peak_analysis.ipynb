# %%
import os
import numpy as np
from scipy.io import wavfile

def preprocess_audio_scipy(file_path, output_directory, target_sample_rate=22000, target_duration=2.0):
    """
    Preprocess audio using SciPy: convert to mono, downsample, trim/pad to 2 seconds, and normalize.
    Args:
        file_path (str): Path to the input audio file.
        output_directory (str): Directory to save the preprocessed file.
        target_sample_rate (int): Desired sampling rate for the audio.
        target_duration (float): Target duration in seconds.
    """
    # Load the audio file
    sample_rate, data = wavfile.read(file_path)

    # Convert to mono if stereo
    if len(data.shape) == 2:
        data = np.mean(data, axis=1).astype(data.dtype)

    # Downsample to the target sample rate
    if sample_rate != target_sample_rate:
        num_samples = int(len(data) * target_sample_rate / sample_rate)
        data = np.interp(
            np.linspace(0, len(data), num_samples, endpoint=False),
            np.arange(len(data)),
            data
        )
        sample_rate = target_sample_rate

    # Trim or pad the audio to the target duration
    target_length = int(sample_rate * target_duration)
    if len(data) > target_length:
        data = data[:target_length]
    elif len(data) < target_length:
        data = np.pad(data, (0, target_length - len(data)), mode='constant')

    # Save the preprocessed file
    os.makedirs(output_directory, exist_ok=True)
    output_file = os.path.join(output_directory, os.path.basename(file_path))
    wavfile.write(output_file, sample_rate, data.astype(np.float32))
    print(f"Saved preprocessed file to: {output_file}")

def process_dataset_scipy(input_directory, output_directory):
    """
    Process all audio files in a directory using SciPy.
    Args:
        input_directory (str): Directory containing the original audio files.
        output_directory (str): Directory to save preprocessed files.
    """
    for file_name in os.listdir(input_directory):
        if file_name.endswith(".wav"):
            file_path = os.path.join(input_directory, file_name)
            preprocess_audio_scipy(file_path, output_directory)

# Define input and output directories
input_directory = "/Users/jakob/Downloads/IDMT_Traffic/audio"
output_directory = "/Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized"

# Process the dataset
process_dataset_scipy(input_directory, output_directory)
# Out:
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1103360_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1033448_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_9062400_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_3036482_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_30814719_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_586040_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_17972736_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1329128_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_127382016_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_318797_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_16542720_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_2563949_M_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_24072192_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_2437632_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_10054400_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_604592_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_2024024_M_W_TR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_1124288_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_19869951_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_79292160_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2237936_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_1151576_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1929080_A_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_438520_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1452376_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_4990719_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_278360_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_67070208_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_985400_A_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_10053120_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_2996736_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1046119_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_64745472_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1182136_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_961752_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1388653_A_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_349037_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_2643853_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_623120_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_605320_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_1210242_A_D_TR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_20703999_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_23708928_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_7530240_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_90520_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_62512128_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_776456_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_817176_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_1057976_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_6977280_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_11546880_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_44865792_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_72816384_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_2461719_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_1544648_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2737431_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1715480_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-16-35_Fraunhofer-IDMT_30Kmh_5637888_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_13364351_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-16-07_Hohenwarte_unknownKmh_3885596_M_D_ML_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_1360088_A_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_1414168_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_14472960_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_25050879_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_887624_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_90299520_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_43425024_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_1916008_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_123257343_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1327352_M_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_18184704_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_6571520_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_94891392_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_3682560_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_150552_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_37884672_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_86714880_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_2631533_M_W_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_66868224_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_35486720_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_24953472_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1040791_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2356077_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_87591552_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_96102272_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_1543928_A_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_2143256_M_D_TR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_61253376_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2261613_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_19398912_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_815456_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_13460351_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_14376960_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1851896_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_705133_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_45806079_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_1412120_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_79496832_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_380024_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_670296_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_67096_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_2602690_A_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1591800_M_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_32835072_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_36890112_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_116548863_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_1779245_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_4414719_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1171616_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-14-02_Hohenwarte_unknownKmh_5199030_M_D_ML_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_30283776_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_551048_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_436440_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-16-07_Hohenwarte_unknownKmh_2012392_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_43666944_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_3209864_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_16058880_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_1815032_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1503848_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-14-02_Hohenwarte_unknownKmh_5294352_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_853112_A_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_2370968_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_23082240_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_2298264_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_291608_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1585613_M_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_62850560_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_61828224_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_102253568_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_10232832_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-14-02_Hohenwarte_unknownKmh_5385811_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_564946_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_2227181_A_D_TR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_100006143_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_30283776_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_792770_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_2477911_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_43666944_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2638592_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_16058880_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_227352_M_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_2334834_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_23082240_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_676664_A_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_79496832_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_3547458_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_1175000_M_D_TR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_32835072_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_36890112_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_116548863_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_4414719_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_2404685_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1019048_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_902120_M_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_100006143_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1317773_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_1938200_A_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_1216856_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2321562_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1877080_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_62850560_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_61828224_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_102253568_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_10232832_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_232304_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_94891392_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_3682560_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_1539074_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2086474_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2192546_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_86714880_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_826952_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_37884672_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1396616_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_2186583_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_35486720_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1569032_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_66868224_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_963842_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_24953472_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2277976_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_812824_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_90299520_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_584386_M_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_43425024_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1658936_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-14-02_Hohenwarte_unknownKmh_2909133_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_123257343_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_872600_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_1288557_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_3067650_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_1111832_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_18184704_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_1847240_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_6571520_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_61253376_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_3377144_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_19398912_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_13460351_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_284072_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_805080_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2262184_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1759304_M_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_14376960_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1048808_A_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_2269333_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_45806079_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1619312_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_683064_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_87591552_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_96102272_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1001312_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_77613_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_2728813_M_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_791320_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_1371416_A_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_20703999_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_23708928_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_784952_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_162072_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_3072301_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_7530240_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2520280_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_64745472_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_3063544_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_3532338_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_966829_M_W_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_461186_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1188632_M_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_698624_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-16-35_Fraunhofer-IDMT_30Kmh_5637888_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1545688_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_13364351_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1381432_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_513016_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_14472960_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_489848_A_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_25050879_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_2877634_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_62512128_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1318040_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_2812962_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_6977280_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_11546880_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1637192_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_44865792_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_72816384_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_1701800_M_W_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_24072192_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-16-07_Hohenwarte_unknownKmh_3216813_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_2437632_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_10054400_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2018040_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1699136_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_2086088_M_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_2565826_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-14-02_Hohenwarte_unknownKmh_1303960_M_D_ML_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_1497624_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1103360_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_1550584_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_9062400_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_700616_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_30814719_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_17972736_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_127382016_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_16542720_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_67070208_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_976066_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_882608_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_10053120_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_2996736_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2123026_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_17576_M_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_3514157_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_165600_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_19869951_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_79292160_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_4990719_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_89004288_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_83133312_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_2020226_A_W_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_28143360_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_828936_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_706832_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_88094976_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_66364416_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-16-30_Langewiesener-Strasse_50Kmh_84117120_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_129000576_SE_CH34-BG.wav
# ...
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_2487552_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_12903936_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_119555583_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_697016_A_D_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_1648088_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_49712640_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_888973_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_11883264_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_65129472_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_24262656_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_7231488_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_143048_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_2675906_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_95600640_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_3267645_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_50486015_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_2043656_M_W_TL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_681864_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_3363592_M_W_BL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_9430272_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_1625384_M_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_35110656_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_1266008_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1654616_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_538392_A_D_TL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_23725824_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_8774400_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_485432_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_12075264_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_34785024_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_53632512_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2660269_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_368312_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_941192_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_34080768_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1584104_M_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_28431360_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_30008_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-30_Schleusinger-Allee_70Kmh_6074880_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_3020909_M_W_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_40455936_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_39094272_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_38663679_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_6587136_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_96930048_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_3550952_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_16095999_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-12-07_Hohenwarte_unknownKmh_6180060_M_D_ML_SE_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_36389376_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_679928_A_W_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_1050477_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1476120_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_22794240_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2020-08-29-16-07_Hohenwarte_unknownKmh_278704_M_D_MR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_28788735_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_977282_M_W_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_42160896_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-10-00_Schleusinger-Allee_70Kmh_9334272_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_35865600_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_4970496_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_1644584_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_117320960_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_34910720_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-08-30_Langewiesener-Strasse_50Kmh_8426112_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_121357824_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_3235976_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_14812160_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_572384_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-08-35_Fraunhofer-IDMT_30Kmh_894296_M_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_47345919_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_1801304_M_D_TR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_114638592_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2869954_A_D_CR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_129592320_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_20840960_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-16-35_Fraunhofer-IDMT_30Kmh_618456_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_1987130_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_661352_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_42604032_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_657895_A_D_TR_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-15-45_Langewiesener-Strasse_50Kmh_564679_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-23-16-20_Fraunhofer-IDMT_30Kmh_1382935_A_D_CL_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-08-40_Fraunhofer-IDMT_30Kmh_5278719_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_69688320_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-16-40_Langewiesener-Strasse_50Kmh_1020584_A_D_CR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-08-00_Schleusinger-Allee_70Kmh_458648_M_W_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_50110464_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_127624959_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_934232_M_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-09-00_Schleusinger-Allee_70Kmh_15870720_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-12-16-00_Schleusinger-Allee_70Kmh_7037952_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-13-15-55_Schleusinger-Allee_70Kmh_1839256_A_D_TR_SE_CH34.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-10-22-15-30_Fraunhofer-IDMT_30Kmh_7814400_ME_CH12-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-07-25_Langewiesener-Strasse_50Kmh_121591680_SE_CH34-BG.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-19-15-25_Langewiesener-Strasse_50Kmh_2399853_A_D_CL_ME_CH12.wav
# Saved preprocessed file to: /Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized/2019-11-18-07-25_Langewiesener-Strasse_50Kmh_45728256_SE_CH34-BG.wav

# %%
# Idee: Peak dB Analysis

import os
import numpy as np
import pandas as pd
from scipy.io import wavfile

# Lade die df_dataset-Datei
df_dataset_path = r"df_dataset.xlsx"  # Passe den Pfad an
df_dataset = pd.read_excel(df_dataset_path)

# Pfad zu den vorverarbeiteten Audiodateien
audio_directory = r'/Users/jakob/Downloads/IDMT_Traffic/preprocessed_audio_not_normalized'

# Funktion zur Berechnung des RMS-Werts
def calculate_rms(file_path):
    """
    Berechnet den RMS-Wert einer Audiodatei.
    Args:
        file_path (str): Pfad zur Audiodatei.
    Returns:
        float: RMS-Wert.
    """
    # Lade die Audiodatei
    sample_rate, data = wavfile.read(file_path)
    if data.ndim == 2:  # Falls Stereo, konvertiere zu Mono
        data = np.mean(data, axis=1)
    # Berechne den RMS-Wert
    rms = np.sqrt(np.mean(data**2))
    return rms

# Liste für RMS-Werte
rms_data = []

# Berechne RMS für jede Datei im Verzeichnis
for file_name in os.listdir(audio_directory):
    if file_name.endswith(".wav"):
        # Berechne RMS
        file_path = os.path.join(audio_directory, file_name)
        rms_value = calculate_rms(file_path)
        
        # Entferne ".wav" aus dem Dateinamen für das Merging
        base_name = file_name.replace(".wav", "")
        
        # Speichere den RMS-Wert und den Dateinamen
        rms_data.append({'file': base_name, 'rms': rms_value})

# Konvertiere RMS-Daten in DataFrame
df_rms = pd.DataFrame(rms_data)

# Merge mit df_dataset anhand der Spalte "file"
df_merged = pd.merge(df_dataset, df_rms, on='file', how='left')

# Speichere die erweiterte Tabelle
output_path = r"df_dataset_with_rms.xlsx"  # Passe den Pfad an
df_merged.to_excel(output_path, index=False)
print(f"Erweiterte Tabelle mit RMS-Werten gespeichert unter: {output_path}")
# Out:
# Erweiterte Tabelle mit RMS-Werten gespeichert unter: df_dataset_with_rms.xlsx

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Load the dataset
df = pd.read_excel(r"df_dataset_with_rms.xlsx")

# Create a subplot with 1 row and 3 columns
fig = make_subplots(
    rows=1, cols=3, 
    subplot_titles=("30 km/h", "50 km/h", "70 km/h"), 
    horizontal_spacing=0.1
)

# Speeds to iterate
speeds = [30, 50, 70]

# Loop through speeds and add box plots to subplots
for i, speed in enumerate(speeds):
    # Filter the data for the current speed
    df_filtered = df[(df['speed_kmh'] == str(speed)) & (df['microphone'] == "SE") & (df['vehicle'] != "M")]
    
    # Create a box plot for the current speed
    fig.add_trace(
        go.Box(
            x=df_filtered['vehicle'],
            y=df_filtered['rms'],
            name=f"{speed} km/h",  # Legend label
            marker=dict(color='blue'),  # Optional: Color
            boxmean=True  # Show mean in the box plot
        ),
        row=1, col=i + 1  # Place in the corresponding subplot
    )

# Update layout for spacing and size
fig.update_layout(
    title_text="RMS in Different Vehicle Categories Across Speeds",
    height=500,
    width=1200,  # Adjust width for side-by-side view
    showlegend=False  # Hide redundant legend
)

# Show the figure
fig.show()

# %%
# Die Variable „df“ wurde aus dem URI geladen: /Users/jakob/Library/CloudStorage/OneDrive-student.kit.edu/Studium/02_Master/4. Semester/seminar/RTN-jakob/df_dataset_merged.xlsx
import pandas as pd
# Load the dataset
df = pd.read_excel(r"df_dataset_with_rms.xlsx")

# Zeilen basierend auf Spalte filtern: 'vehicle'
df = df[df['vehicle'] == "C"]

# Zeilen basierend auf Spalte filtern: 'microphone'
df = df[df['microphone'] == "SE"]

import pandas as pd
import plotly.express as px

# Erstelle den Boxplot
fig = px.box(
    df,
    x='speed_kmh',  # Fahrzeugklassen (z. B. Bus, Car, Motorcycle, Truck)
    y='rms',
    title='RMS for Car at 30, 50, 70kmh',
    labels={'vehicle': 'Vehicle Class', 'rms': 'Root Mean Square'},
    color='vehicle',  # Optional: Farben für verschiedene Fahrzeugklassen
    category_orders={'speed_kmh': [30, 50, 70]}  # Feste Reihenfolge für die x-Achse
)

fig.update_layout(
    height=500,
    width=500,  # Adjust width for side-by-side view
    showlegend=False  # Hide redundant legend
)

# Zeige den Plot
fig.show()

# %%
import os
import numpy as np
import pandas as pd
from scipy.io import wavfile

def calculate_peak_loudness(file_path):
    """
    Calculate peak loudness (dBFS) for an audio file.
    Args:
        file_path (str): Path to the WAV audio file.
    Returns:
        float: Peak loudness in dBFS.
    """
    # Load audio
    sample_rate, data = wavfile.read(file_path)

    # Convert to mono if stereo
    if len(data.shape) == 2:
        data = np.mean(data, axis=1).astype(data.dtype)

    # Calculate peak amplitude
    peak_amplitude = np.max(np.abs(data))

    # Define full-scale amplitude based on audio format
    if np.issubdtype(data.dtype, np.integer):
        full_scale_amplitude = np.iinfo(data.dtype).max
    elif np.issubdtype(data.dtype, np.floating):
        full_scale_amplitude = 1.0  # Assuming normalized float format
    else:
        raise ValueError(f"Unsupported data type: {data.dtype}")

    # Calculate peak loudness in dBFS
    if peak_amplitude == 0:
        peak_loudness = -np.inf  # Handle silence case
    else:
        peak_loudness = 20 * np.log10(peak_amplitude / full_scale_amplitude)

    return peak_loudness

# Path to the dataset and original audio files
df_dataset_path = "df_dataset.xlsx"  # Path to the dataset
audio_directory = "/Users/jakob/Downloads/IDMT_Traffic/audio"  # Original audio files directory

# Load the dataset
df_dataset = pd.read_excel(df_dataset_path)

# Initialize a list to store peak loudness data
peak_loudness_data = []

# Loop through each audio file in the directory
for file_name in os.listdir(audio_directory):
    if file_name.endswith(".wav"):
        file_path = os.path.join(audio_directory, file_name)
        
        # Calculate peak loudness
        try:
            peak_loudness = calculate_peak_loudness(file_path)
        except Exception as e:
            print(f"Error processing file {file_name}: {e}")
            continue

        # Remove ".wav" for merging compatibility
        base_name = file_name.replace(".wav", "")
        
        # Append results to the list
        peak_loudness_data.append({'file': base_name, 'peak_loudness': peak_loudness})

# Convert the peak loudness data to a DataFrame
df_peak_loudness = pd.DataFrame(peak_loudness_data)

# Merge with the original dataset based on the 'file' column
df_dataset_peak_loudness = pd.merge(df_dataset, df_peak_loudness, on='file', how='left')

# Save the merged dataset to a new Excel file
output_path = "df_dataset_peak_loudness.xlsx"
df_dataset_peak_loudness.to_excel(output_path, index=False)

print(f"Merged dataset with peak loudness saved to: {output_path}")
# Out:
# Merged dataset with peak loudness saved to: df_dataset_peak_loudness.xlsx

# %%
# Die Variable „df“ wurde aus dem URI geladen: /Users/jakob/Library/CloudStorage/OneDrive-student.kit.edu/Studium/02_Master/4. Semester/seminar/RTN-jakob/df_dataset_merged.xlsx
import pandas as pd
# Load the dataset
df = pd.read_excel(r"df_dataset_peak_loudness.xlsx")

# Zeilen basierend auf Spalte filtern: 'vehicle'
df = df[df['vehicle'] == "T"]

# Zeilen basierend auf Spalte filtern: 'microphone'
df = df[df['microphone'] == "SE"]

import pandas as pd
import plotly.express as px

# Erstelle den Boxplot
fig = px.box(
    df,
    x='speed_kmh',  # Fahrzeugklassen (z. B. Bus, Car, Motorcycle, Truck)
    y='peak_loudness',
    title='Peak Loudness for Car at 30, 50, 70kmh',
    category_orders={'speed_kmh': [30, 50, 70]}  # Feste Reihenfolge für die x-Achse
)

fig.update_layout(
    height=500,
    width=500,  # Adjust width for side-by-side view
    showlegend=False  # Hide redundant legend
)

# Zeige den Plot
fig.show()
