# %% [markdown]
# <p> Der erste Koeffizient beschreibt die allgemeine Energie des Spektrums</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/05. WS_2024_25/Seminar RTN/Code/RTN-jakob/df_dataset_mfcc_merged.xlsx")
#drop columns
columns_to_drop = ['sample_pos', 'channel', 'date_time', 'daytime']
df.drop(columns=columns_to_drop, inplace=True)
#remove rows with no vehicle type 
df = df[df["vehicle"].notna()]
#change data type
df["vehilce"] = df["vehicle"].astype("category")
#remove outliers
df = df[df["mfcc_1"] >= 0]

# %%
mfcc_columns = [col for col in df.columns if col.startswith("mfcc")]

fig, axes = plt.subplots(len(mfcc_columns), 1, figsize=(40,100))

for i, col in enumerate(mfcc_columns): 
    sns.boxplot(data=df, x="vehicle", y=df[col], ax=axes[i], palette=sns.color_palette("GnBu"))
    axes[i].set_title(f"Boxplot for {col}")
    axes[i].set_xlabel("vehicle type")
    axes[i].set_ylabel(col)

# %%
fig, axes = plt.subplots(len(mfcc_columns), 1, figsize=(40,100))

for i, col in enumerate(mfcc_columns): 
    sns.boxplot(data=df, x="speed_kmh", y=df[col], ax=axes[i], palette=sns.color_palette("GnBu"))
    axes[i].set_title(f"Boxplot for {col}")
    axes[i].set_xlabel("speed_kmh")
    axes[i].set_ylabel(col)

# %%
fig, axes = plt.subplots(len(mfcc_columns), 1, figsize=(40,100))

for i, col in enumerate(mfcc_columns): 
    sns.histplot(data=df, x=df[col], ax=axes[i], palette=sns.color_palette("GnBu"))
    axes[i].set_title(f"Histogram for {col}")
    axes[i].set_xlabel(col)
# Out:
# /var/folders/xt/qp4h10d92h76_sfj0rh4m3v00000gn/T/ipykernel_15153/815600753.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=df[col], ax=axes[i], palette=sns.color_palette("GnBu"))
# /Users/janikwahrheit/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/xt/qp4h10d92h76_sfj0rh4m3v00000gn/T/ipykernel_15153/815600753.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x=df[col], ax=axes[i], palette=sns.color_palette("GnBu"))
# ...
