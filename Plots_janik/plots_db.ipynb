# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os 
from scipy.io import wavfile

# %%
df_cleaned = pd.read_csv("/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/05. WS_2024_25/Seminar RTN/Code/CleanData.csv")
df_cleaned = df_cleaned[df_cleaned["Dezibel_ber"] > 0]
df_uncleaned = pd.read_excel("/Users/janikwahrheit/Library/CloudStorage/OneDrive-Persönlich/01_Studium/01_Bachelor/05. WS_2024_25/Seminar RTN/Code/Uncleaned.xlsx")

# %%
def set_hist(df, ax, title):
    sns.histplot(data=df, x="Dezibel_ber",binrange=(0, 80), palette=sns.color_palette("Paired"), ax=axes[ax])
    axes[ax].set_title(title)

def set_box(df, ax, title, cat): 
    sns.boxplot(data=df, x=df[cat], y="Dezibel_ber", ax=axes[ax], palette=sns.color_palette("Paired"))
    axes[ax].set_title(title)

# %% [markdown]
# <h2>Histograms</h2>

# %%
fig, axes = plt.subplots(1,2, figsize=(20,5))
set_hist(df_uncleaned, 0, "Uncleaned")
set_hist(df_cleaned, 1, "Cleaned")
plt.savefig("histograms.svg")
# Out:
# /var/folders/xt/qp4h10d92h76_sfj0rh4m3v00000gn/T/ipykernel_8880/2424103659.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x="Dezibel_ber",binrange=(0, 80), palette=sns.color_palette("Paired"), ax=axes[ax])
# /Users/janikwahrheit/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/xt/qp4h10d92h76_sfj0rh4m3v00000gn/T/ipykernel_8880/2424103659.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x="Dezibel_ber",binrange=(0, 80), palette=sns.color_palette("Paired"), ax=axes[ax])
# ...

# %% [markdown]
# <h2>Boxplots/Vehicle Type</h2>

# %%
fig, axes = plt.subplots(1,2, figsize=(20,5))
set_box(df_uncleaned, 0, "Uncleaned", "vehicle")
set_box(df_cleaned, 1, "Cleaned", "vehicle")
plt.savefig("boxplots_vehcile.svg")

# %% [markdown]
# <h2>Boxplots/Speed</h2>

# %%
fig, axes = plt.subplots(1,2, figsize=(20,5))
set_box(df_uncleaned, 0, "Uncleaned", "speed_kmh")
set_box(df_cleaned, 1, "Cleaned", "speed_kmh")
plt.savefig("boxplots_speed.svg")

# %% [markdown]
# <h2>Boxplot/Location</h2>

# %%
fig, axes = plt.subplots(1,2, figsize=(20,5))
set_box(df_uncleaned, 0, "Uncleaned", "location")
set_box(df_cleaned, 1, "Cleaned", "location")#
plt.savefig("boxplots_location.svg")
