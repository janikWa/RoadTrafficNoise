# %% [markdown]
# ### Packages

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load data

# %%
data_path = '../IDMT-Traffic/datasets/df_main_encoded_only.csv'  
df = pd.read_csv(data_path)
df = df.drop(columns=['file', 'Unnamed: 0', 'is_background_encoded'])

# %% [markdown]
# ### Correlation Analysis

# %%
# --- Schritt 1: Korrelationsanalyse und initiale Feature-Selektion ---
def remove_highly_correlated_features(df, threshold=0.9):
    correlation_matrix = df.corr().abs()
    upper_triangle = correlation_matrix.where(
        np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool)
    )
    
    # Finden der hoch korrelierten Features
    to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]
    return df.drop(columns=to_drop), to_drop

# --- Schritt 2: Modelltraining und Speicherung der wichtigen Features ---
def train_and_evaluate(X, y, threshold=0.85):
    # Train-Test-Split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Modell initialisieren und trainieren
    log_reg = LogisticRegression(max_iter=1000, random_state=42)
    log_reg.fit(X_train, y_train)

    # Vorhersagen und Metriken
    y_pred = log_reg.predict(X_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))

    # Extraktion der wichtigen Features
    important_features = pd.Series(log_reg.coef_[0], index=X.columns)
    important_features = important_features[important_features.abs() > threshold]
    return important_features, log_reg

# --- Schritt 3: Analyse der wichtigen Features ---
def analyze_important_features(df, important_features):
    # Korrelationsmatrix für wichtige Features
    important_corr = df[important_features.index].corr()
    print("Correlation Matrix of Important Features:")
    print(important_corr)
    return important_corr

# %%
# --- Anwendung der Pipeline ---
# Daten vorbereiten
path = '../IDMT-Traffic/datasets/df_main_encoded_only.csv' 
df = pd.read_csv(path)
df = df.drop(columns=['file', 'Unnamed: 0', 'is_background_encoded'])

target = 'daytime_encoded'
X = df.drop(columns=[target])
y = df[target]

# Initialisierung der Parameter
corr_threshold = 0.95
coef_threshold = 0.85
iterations = 3

# Ergebnisse speichern
used_features = []
current_df = X.copy()

for iteration in range(iterations):
    print(f"\n--- Iteration {iteration + 1} ---")

    # Schritt 1: Entfernen hoch korrelierter Features
    current_df, dropped_features = remove_highly_correlated_features(current_df, threshold=corr_threshold)
    print(f"Dropped Features due to high correlation: {dropped_features}")

    # Schritt 2: Modelltraining und wichtige Features speichern
    important_features, model = train_and_evaluate(current_df, y, threshold=coef_threshold)
    print(f"Important Features (>|{coef_threshold}|): {list(important_features.index)}")

    # Schritt 3: Analyse der wichtigen Features
    analyze_important_features(df, important_features)

    # Speichern der verwendeten Features
    used_features.append(list(current_df.columns))
    with open(f"features_iteration_{iteration + 1}.txt", "w") as f:
        f.write(f"Iteration {iteration + 1} Features:\n")
        f.write("\n".join(current_df.columns))
# Out:
# --- Iteration 1 ---
# Dropped Features due to high correlation: ['band_2_dB', 'band_14_dB', 'band_15_dB', 'band_16_dB', 'band_17_dB', 'band_18_dB', 'band_19_dB', 'band_20_dB', 'band_21_dB', 'band_22_dB', 'band_23_dB', 'band_24_dB', 'band_25_dB', 'band_26_dB', 'band_27_dB', 'band_28_dB', 'band_29_dB', 'peak_dB_2', 'peak_dB_3', 'octband_dB_mean']
# c:\Users\Anton\anaconda3\envs\traffic_noise\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.893556425774297
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1645
#            1       0.88      0.86      0.87      1164
#
#     accuracy                           0.89      2809
#    macro avg       0.89      0.89      0.89      2809
# weighted avg       0.89      0.89      0.89      2809
#
# Important Features (>|0.85|): ['mfcc_2']
# Correlation Matrix of Important Features:
#         mfcc_2
# mfcc_2     1.0
#
# --- Iteration 2 ---
# Dropped Features due to high correlation: []
# c:\Users\Anton\anaconda3\envs\traffic_noise\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.893556425774297
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1645
#            1       0.88      0.86      0.87      1164
#
#     accuracy                           0.89      2809
#    macro avg       0.89      0.89      0.89      2809
# weighted avg       0.89      0.89      0.89      2809
#
# Important Features (>|0.85|): ['mfcc_2']
# Correlation Matrix of Important Features:
#         mfcc_2
# mfcc_2     1.0
#
# --- Iteration 3 ---
# Dropped Features due to high correlation: []
# Accuracy: 0.893556425774297
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      1645
#            1       0.88      0.86      0.87      1164
#
#     accuracy                           0.89      2809
#    macro avg       0.89      0.89      0.89      2809
# weighted avg       0.89      0.89      0.89      2809
#
# Important Features (>|0.85|): ['mfcc_2']
# Correlation Matrix of Important Features:
#         mfcc_2
# mfcc_2     1.0
# c:\Users\Anton\anaconda3\envs\traffic_noise\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# performance is just getting worse after deleting features that are highly correlated. Take another approach.

# %% [markdown]
# ## Iterative Approach

# %%
# Zielvariable und Features festlegen
target = 'daytime_encoded'
X = df.drop(columns=[target])  # Features
y = df[target]  # Zielvariable

# Trainings- und Testdaten splitten
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Modelle initialisieren
models = {
    "LogisticRegression": LogisticRegression(max_iter=1000, random_state=42),
    "RandomForest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(random_state=42, eval_metric="logloss")
}

# Ergebnisse speichern
results = []
deleted_features_logreg = []
deleted_features_rf = []
deleted_features_xgb = []

# Iterativer Ansatz
for model_name, model in models.items():
    current_X_train = X_train.copy()
    iteration = 0

    while current_X_train.shape[1] > 40:  # Solange noch mindestens ein Feature übrig ist
        # Pipeline erstellen (Skalierung und Modell)
        pipeline = Pipeline([
            ('scaler', StandardScaler()),  # Standardisierung
            ('model', model)
        ])

        # Modell trainieren
        pipeline.fit(current_X_train, y_train)

        # Wichtigste Features extrahieren
        if model_name == "LogisticRegression":
            importance = np.abs(model.coef_[0])  # Gewichtungen der Features
        elif model_name == "RandomForest" or model_name == "XGBoost":
            importance = model.feature_importances_

        important_features = pd.Series(importance, index=current_X_train.columns)
        important_features = important_features.sort_values(ascending=False)

        # Genauigkeit berechnen
        y_pred = pipeline.predict(X_test[current_X_train.columns])
        accuracy = accuracy_score(y_test, y_pred)
        confusionmatrix = confusion_matrix(y_test, y_pred)

        # Ergebnis speichern
        results.append({
            "Model": model_name,
            "Iteration": iteration,
            "Accuracy": accuracy,
            "Confusion Matrix": confusionmatrix,
            "Dropped Feature": important_features.index[0],
            "Feature Importance": important_features.iloc[0],
            "Remaining Features": len(current_X_train.columns)
        })

        # Entfernte Features pro Modell speichern
        if model_name == "LogisticRegression":
            deleted_features_logreg.append(important_features.index[0])
        elif model_name == "RandomForest":
            deleted_features_rf.append(important_features.index[0])
        elif model_name == "XGBoost":
            deleted_features_xgb.append(important_features.index[0])

        # Ausgabe in der Konsole
        print(f"Model: {model_name}, Iteration: {iteration}, Accuracy: {accuracy:.4f}, Confusion Mx: {confusionmatrix} "
              f"Dropped Feature: {important_features.index[0]}, Feature Importance: {important_features.iloc[0]:.4f}")

        # Ergebnis in Datei speichern
        with open(f"{model_name}_feature_dropping_results.txt", "a") as file:
            file.write(f"Iteration: {iteration}, Accuracy: {accuracy:.4f}, "
                       f"Confusion Matrix: {confusionmatrix}, "
                       f"Dropped Feature: {important_features.index[0]}, "
                       f"Feature Importance: {important_features.iloc[0]:.4f}, "
                       f"Remaining Features: {len(current_X_train.columns)}\n")

        # Wichtigstes Feature droppen
        current_X_train = current_X_train.drop(columns=[important_features.index[0]])

        # Iteration erhöhen
        iteration += 1

# Ergebnisse als DataFrame anzeigen
results_df = pd.DataFrame(results)
print("\nAbschließende Ergebnisse:\n", results_df)
# Out:
# Model: LogisticRegression, Iteration: 0, Accuracy: 0.9053, Confusion Mx: [[1525  117]
#  [ 149 1018]] Dropped Feature: mfcc_2, Feature Importance: 2.3759
# Model: LogisticRegression, Iteration: 1, Accuracy: 0.9078, Confusion Mx: [[1530  112]
#  [ 147 1020]] Dropped Feature: band_24_dB, Feature Importance: 2.8380
# Model: LogisticRegression, Iteration: 2, Accuracy: 0.9078, Confusion Mx: [[1533  109]
#  [ 150 1017]] Dropped Feature: band_25_dB, Feature Importance: 2.2989
# Model: LogisticRegression, Iteration: 3, Accuracy: 0.9078, Confusion Mx: [[1533  109]
#  [ 150 1017]] Dropped Feature: band_19_dB, Feature Importance: 1.8524
# Model: LogisticRegression, Iteration: 4, Accuracy: 0.9064, Confusion Mx: [[1532  110]
#  [ 153 1014]] Dropped Feature: band_26_dB, Feature Importance: 1.6340
# Model: LogisticRegression, Iteration: 5, Accuracy: 0.9060, Confusion Mx: [[1530  112]
#  [ 152 1015]] Dropped Feature: channel_encoded, Feature Importance: 1.6536
# Model: LogisticRegression, Iteration: 6, Accuracy: 0.9057, Confusion Mx: [[1528  114]
#  [ 151 1016]] Dropped Feature: location_encoded, Feature Importance: 1.9904
# Model: LogisticRegression, Iteration: 7, Accuracy: 0.8993, Confusion Mx: [[1517  125]
#  [ 158 1009]] Dropped Feature: mfcc_3, Feature Importance: 2.1519
# Model: LogisticRegression, Iteration: 8, Accuracy: 0.8950, Confusion Mx: [[1507  135]
#  [ 160 1007]] Dropped Feature: band_29_dB, Feature Importance: 2.6887
# Model: LogisticRegression, Iteration: 9, Accuracy: 0.8928, Confusion Mx: [[1506  136]
#  [ 165 1002]] Dropped Feature: band_28_dB, Feature Importance: 3.7505
# Model: LogisticRegression, Iteration: 10, Accuracy: 0.8918, Confusion Mx: [[1509  133]
#  [ 171  996]] Dropped Feature: band_27_dB, Feature Importance: 5.8678
# Model: LogisticRegression, Iteration: 11, Accuracy: 0.8871, Confusion Mx: [[1510  132]
#  [ 185  982]] Dropped Feature: octband_dB_mean, Feature Importance: 11.8320
# Model: LogisticRegression, Iteration: 12, Accuracy: 0.8775, Confusion Mx: [[1502  140]
#  [ 204  963]] Dropped Feature: peak_dB_1, Feature Importance: 4.6819
# Model: LogisticRegression, Iteration: 13, Accuracy: 0.8565, Confusion Mx: [[1479  163]
#  [ 240  927]] Dropped Feature: peak_dB_2, Feature Importance: 4.4949
# Model: LogisticRegression, Iteration: 14, Accuracy: 0.8448, Confusion Mx: [[1460  182]
#  [ 254  913]] Dropped Feature: peak_dB_3, Feature Importance: 5.2342
# Model: LogisticRegression, Iteration: 15, Accuracy: 0.8302, Confusion Mx: [[1442  200]
#  [ 277  890]] Dropped Feature: band_22_dB, Feature Importance: 3.0990
# Model: LogisticRegression, Iteration: 16, Accuracy: 0.8330, Confusion Mx: [[1447  195]
#  [ 274  893]] Dropped Feature: band_18_dB, Feature Importance: 1.9518
# Model: RandomForest, Iteration: 0, Accuracy: 0.9559, Confusion Mx: [[1596   46]
#  [  78 1089]] Dropped Feature: mfcc_2, Feature Importance: 0.1727
# Model: RandomForest, Iteration: 1, Accuracy: 0.9569, Confusion Mx: [[1589   53]
#  [  68 1099]] Dropped Feature: band_29_dB, Feature Importance: 0.1268
# Model: RandomForest, Iteration: 2, Accuracy: 0.9587, Confusion Mx: [[1595   47]
#  [  69 1098]] Dropped Feature: band_28_dB, Feature Importance: 0.1355
# Model: RandomForest, Iteration: 3, Accuracy: 0.9541, Confusion Mx: [[1591   51]
#  [  78 1089]] Dropped Feature: band_27_dB, Feature Importance: 0.1357
# Model: RandomForest, Iteration: 4, Accuracy: 0.9569, Confusion Mx: [[1598   44]
#  [  77 1090]] Dropped Feature: mfcc_1, Feature Importance: 0.1513
# Model: RandomForest, Iteration: 5, Accuracy: 0.9591, Confusion Mx: [[1590   52]
#  [  63 1104]] Dropped Feature: band_26_dB, Feature Importance: 0.1602
# Model: RandomForest, Iteration: 6, Accuracy: 0.9683, Confusion Mx: [[1603   39]
#  [  50 1117]] Dropped Feature: date_time_encoded, Feature Importance: 0.1755
# Model: RandomForest, Iteration: 7, Accuracy: 0.9114, Confusion Mx: [[1534  108]
#  [ 141 1026]] Dropped Feature: band_25_dB, Feature Importance: 0.1600
# Model: RandomForest, Iteration: 8, Accuracy: 0.8964, Confusion Mx: [[1519  123]
#  [ 168  999]] Dropped Feature: mfcc_3, Feature Importance: 0.1047
# Model: RandomForest, Iteration: 9, Accuracy: 0.8491, Confusion Mx: [[1476  166]
#  [ 258  909]] Dropped Feature: band_24_dB, Feature Importance: 0.0825
# Model: RandomForest, Iteration: 10, Accuracy: 0.8373, Confusion Mx: [[1485  157]
#  [ 300  867]] Dropped Feature: weather_encoded, Feature Importance: 0.0593
# Model: RandomForest, Iteration: 11, Accuracy: 0.7971, Confusion Mx: [[1500  142]
#  [ 428  739]] Dropped Feature: octband_dB_mean, Feature Importance: 0.0591
# Model: RandomForest, Iteration: 12, Accuracy: 0.7732, Confusion Mx: [[1487  155]
#  [ 482  685]] Dropped Feature: mfcc_4, Feature Importance: 0.0632
# Model: RandomForest, Iteration: 13, Accuracy: 0.7405, Confusion Mx: [[1481  161]
#  [ 568  599]] Dropped Feature: band_23_dB, Feature Importance: 0.0554
# Model: RandomForest, Iteration: 14, Accuracy: 0.7220, Confusion Mx: [[1472  170]
#  [ 611  556]] Dropped Feature: mfcc_5, Feature Importance: 0.0501
# Model: RandomForest, Iteration: 15, Accuracy: 0.7102, Confusion Mx: [[1481  161]
#  [ 653  514]] Dropped Feature: speed_kmh_encoded, Feature Importance: 0.0345
# Model: RandomForest, Iteration: 16, Accuracy: 0.7059, Confusion Mx: [[1477  165]
#  [ 661  506]] Dropped Feature: mfcc_8, Feature Importance: 0.0336
# Model: XGBoost, Iteration: 0, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_29_dB, Feature Importance: 0.2665
# Model: XGBoost, Iteration: 1, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_28_dB, Feature Importance: 0.2920
# Model: XGBoost, Iteration: 2, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: mfcc_2, Feature Importance: 0.2863
# Model: XGBoost, Iteration: 3, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: mfcc_1, Feature Importance: 0.2174
# Model: XGBoost, Iteration: 4, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: channel_encoded, Feature Importance: 0.2001
# Model: XGBoost, Iteration: 5, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_27_dB, Feature Importance: 0.1656
# Model: XGBoost, Iteration: 6, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: peak_dB_3, Feature Importance: 0.1786
# Model: XGBoost, Iteration: 7, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_26_dB, Feature Importance: 0.1252
# Model: XGBoost, Iteration: 8, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: location_encoded, Feature Importance: 0.1931
# Model: XGBoost, Iteration: 9, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: mfcc_3, Feature Importance: 0.1272
# Model: XGBoost, Iteration: 10, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_25_dB, Feature Importance: 0.1573
# Model: XGBoost, Iteration: 11, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: weather_encoded, Feature Importance: 0.3849
# Model: XGBoost, Iteration: 12, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: band_14_dB, Feature Importance: 0.5021
# Model: XGBoost, Iteration: 13, Accuracy: 1.0000, Confusion Mx: [[1642    0]
#  [   0 1167]] Dropped Feature: date_time_encoded, Feature Importance: 0.3542
# Model: XGBoost, Iteration: 14, Accuracy: 0.8548, Confusion Mx: [[1484  158]
#  [ 250  917]] Dropped Feature: speed_kmh_encoded, Feature Importance: 0.1108
# Model: XGBoost, Iteration: 15, Accuracy: 0.8402, Confusion Mx: [[1472  170]
#  [ 279  888]] Dropped Feature: mfcc_4, Feature Importance: 0.0722
# Model: XGBoost, Iteration: 16, Accuracy: 0.8526, Confusion Mx: [[1473  169]
#  [ 245  922]] Dropped Feature: microphone_encoded, Feature Importance: 0.0913
#
# Abschließende Ergebnisse:
#                   Model  Iteration  Accuracy            Confusion Matrix  \
# 0   LogisticRegression          0  0.905304  [[1525, 117], [149, 1018]]
# 1   LogisticRegression          1  0.907796  [[1530, 112], [147, 1020]]
# 2   LogisticRegression          2  0.907796  [[1533, 109], [150, 1017]]
# 3   LogisticRegression          3  0.907796  [[1533, 109], [150, 1017]]
# 4   LogisticRegression          4  0.906372  [[1532, 110], [153, 1014]]
# 5   LogisticRegression          5  0.906016  [[1530, 112], [152, 1015]]
# 6   LogisticRegression          6  0.905660  [[1528, 114], [151, 1016]]
# 7   LogisticRegression          7  0.899252  [[1517, 125], [158, 1009]]
# 8   LogisticRegression          8  0.894980  [[1507, 135], [160, 1007]]
# 9   LogisticRegression          9  0.892844  [[1506, 136], [165, 1002]]
# 10  LogisticRegression         10  0.891776   [[1509, 133], [171, 996]]
# 11  LogisticRegression         11  0.887148   [[1510, 132], [185, 982]]
# 12  LogisticRegression         12  0.877536   [[1502, 140], [204, 963]]
# 13  LogisticRegression         13  0.856533   [[1479, 163], [240, 927]]
# 14  LogisticRegression         14  0.844785   [[1460, 182], [254, 913]]
# 15  LogisticRegression         15  0.830189   [[1442, 200], [277, 890]]
# 16  LogisticRegression         16  0.833037   [[1447, 195], [274, 893]]
# 17        RandomForest          0  0.955856    [[1596, 46], [78, 1089]]
# 18        RandomForest          1  0.956924    [[1589, 53], [68, 1099]]
# 19        RandomForest          2  0.958704    [[1595, 47], [69, 1098]]
# 20        RandomForest          3  0.954076    [[1591, 51], [78, 1089]]
# 21        RandomForest          4  0.956924    [[1598, 44], [77, 1090]]
# 22        RandomForest          5  0.959060    [[1590, 52], [63, 1104]]
# 23        RandomForest          6  0.968316    [[1603, 39], [50, 1117]]
# 24        RandomForest          7  0.911356  [[1534, 108], [141, 1026]]
# 25        RandomForest          8  0.896404   [[1519, 123], [168, 999]]
# 26        RandomForest          9  0.849057   [[1476, 166], [258, 909]]
# 27        RandomForest         10  0.837309   [[1485, 157], [300, 867]]
# 28        RandomForest         11  0.797081   [[1500, 142], [428, 739]]
# 29        RandomForest         12  0.773229   [[1487, 155], [482, 685]]
# 30        RandomForest         13  0.740477   [[1481, 161], [568, 599]]
# 31        RandomForest         14  0.721965   [[1472, 170], [611, 556]]
# 32        RandomForest         15  0.710217   [[1481, 161], [653, 514]]
# 33        RandomForest         16  0.705945   [[1477, 165], [661, 506]]
# 34             XGBoost          0  1.000000      [[1642, 0], [0, 1167]]
# 35             XGBoost          1  1.000000      [[1642, 0], [0, 1167]]
# 36             XGBoost          2  1.000000      [[1642, 0], [0, 1167]]
# 37             XGBoost          3  1.000000      [[1642, 0], [0, 1167]]
# 38             XGBoost          4  1.000000      [[1642, 0], [0, 1167]]
# 39             XGBoost          5  1.000000      [[1642, 0], [0, 1167]]
# 40             XGBoost          6  1.000000      [[1642, 0], [0, 1167]]
# 41             XGBoost          7  1.000000      [[1642, 0], [0, 1167]]
# 42             XGBoost          8  1.000000      [[1642, 0], [0, 1167]]
# 43             XGBoost          9  1.000000      [[1642, 0], [0, 1167]]
# 44             XGBoost         10  1.000000      [[1642, 0], [0, 1167]]
# 45             XGBoost         11  1.000000      [[1642, 0], [0, 1167]]
# 46             XGBoost         12  1.000000      [[1642, 0], [0, 1167]]
# 47             XGBoost         13  1.000000      [[1642, 0], [0, 1167]]
# 48             XGBoost         14  0.854753   [[1484, 158], [250, 917]]
# 49             XGBoost         15  0.840157   [[1472, 170], [279, 888]]
# 50             XGBoost         16  0.852617   [[1473, 169], [245, 922]]
#
#        Dropped Feature  Feature Importance  Remaining Features
# 0               mfcc_2            2.375894                  57
# 1           band_24_dB            2.837969                  56
# 2           band_25_dB            2.298884                  55
# 3           band_19_dB            1.852402                  54
# 4           band_26_dB            1.634044                  53
# 5      channel_encoded            1.653642                  52
# 6     location_encoded            1.990351                  51
# 7               mfcc_3            2.151923                  50
# 8           band_29_dB            2.688687                  49
# 9           band_28_dB            3.750523                  48
# 10          band_27_dB            5.867778                  47
# 11     octband_dB_mean           11.832004                  46
# 12           peak_dB_1            4.681900                  45
# 13           peak_dB_2            4.494868                  44
# 14           peak_dB_3            5.234180                  43
# 15          band_22_dB            3.099019                  42
# 16          band_18_dB            1.951806                  41
# 17              mfcc_2            0.172685                  57
# 18          band_29_dB            0.126833                  56
# 19          band_28_dB            0.135471                  55
# 20          band_27_dB            0.135730                  54
# 21              mfcc_1            0.151257                  53
# 22          band_26_dB            0.160227                  52
# 23   date_time_encoded            0.175471                  51
# 24          band_25_dB            0.160039                  50
# 25              mfcc_3            0.104667                  49
# 26          band_24_dB            0.082480                  48
# 27     weather_encoded            0.059297                  47
# 28     octband_dB_mean            0.059081                  46
# 29              mfcc_4            0.063187                  45
# 30          band_23_dB            0.055378                  44
# 31              mfcc_5            0.050141                  43
# 32   speed_kmh_encoded            0.034472                  42
# 33              mfcc_8            0.033643                  41
# 34          band_29_dB            0.266526                  57
# 35          band_28_dB            0.292024                  56
# 36              mfcc_2            0.286323                  55
# 37              mfcc_1            0.217384                  54
# 38     channel_encoded            0.200085                  53
# 39          band_27_dB            0.165631                  52
# 40           peak_dB_3            0.178623                  51
# 41          band_26_dB            0.125239                  50
# 42    location_encoded            0.193120                  49
# 43              mfcc_3            0.127179                  48
# 44          band_25_dB            0.157303                  47
# 45     weather_encoded            0.384948                  46
# 46          band_14_dB            0.502127                  45
# 47   date_time_encoded            0.354156                  44
# 48   speed_kmh_encoded            0.110774                  43
# 49              mfcc_4            0.072208                  42
# 50  microphone_encoded            0.091278                  41

# %%
# Visualization
def plot_feature_dropping(results_df, model_name):
    fig, ax = plt.subplots(figsize=(10, 10))

    # Primäre Achse: Genauigkeit
    ax.set_xlabel('Number of features removed (highest importance first)')
    ax.set_ylabel('Accuracy', color='tab:blue')
    ax.plot(results_df['Iteration'], results_df['Accuracy'], label='Accuracy', color='tab:blue', marker='o')
    ax.tick_params(axis='y', labelcolor='tab:blue')
    ax.set_ylim(0.6, 1.05)  # Grenzen der Accuracy anpassen

    # Titel und Legende
    plt.title(f"Feature Dropping Process for {model_name}")
    fig.tight_layout()  # Layout anpassen
    plt.show()

# Visualisierung für jedes Modell separat
for model_name in models.keys():
    model_results_df = results_df[results_df['Model'] == model_name]
    plot_feature_dropping(model_results_df, model_name)

# %%
# Visualization
def plot_feature_dropping(results_df, model_name):
    fig, ax1 = plt.subplots(figsize=(10, 6))

    # Primäre Achse: Genauigkeit
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Accuracy', color='tab:blue')
    ax1.plot(results_df['Iteration'], results_df['Accuracy'], label='Accuracy', color='tab:blue', marker='o')
    ax1.tick_params(axis='y', labelcolor='tab:blue')
    ax1.set_ylim(0.5, 1.05)  # Grenzen der Accuracy anpassen

    # Sekundäre Achse: Anzahl der verbleibenden Features
    ax2 = ax1.twinx()
    ax2.set_ylabel('Remaining Features', color='tab:red')
    ax2.plot(results_df['Iteration'], results_df['Remaining Features'], label='Remaining Features', color='tab:red', marker='x')
    ax2.tick_params(axis='y', labelcolor='tab:red')

    # Titel und Legende
    plt.title(f"Feature Dropping Process for {model_name}")
    fig.tight_layout()  # Layout anpassen
    plt.show()


# Visualisierung für jedes Modell separat
for model_name in models.keys():
    model_results_df = results_df[results_df['Model'] == model_name]
    plot_feature_dropping(model_results_df, model_name)

# %% [markdown]
# Notes:
#
# Performance of Logistic Regression is not really improved by feature deletion. Deletion of features 1-6 bring slight or no changes with feature 6 being location_encoded.
#
# All deleted Features for improvement:
#
# mfcc_2
# band_24_dB
# band_25_dB
# band_19_dB
# band_26_dB
# channel_encoded
# location_encoded
# mfcc_3
# band_29_dB
# band_28_dB
#
#
# Performance of Random Forest is improved by feature deletion of features 0-6 with feature six being date_time_encoded.
#
# All deleted Features for improvement:
#
# mfcc_2
# band_29_dB
# band_28_dB
# band_27_dB
# mfcc_1
# band_26_dB
# date_time_encoded
#
# XG Bosst has a problem because of accuracy = 100%. Performance of XG Boost can by normalized by feature deletion of features 1-13 with feature 13 being date_time_encoded.
#
# All deleted Features for improvement:
#
# mfcc_8
# band_29_dB
# band_28_dB
# mfcc_2
# mfcc_1
# channel_encoded
# band_27_dB
# peak_dB_3
# band_26_dB
# location_encoded
# mfcc_3
# band_25_dB
# weather_encoded
# band_14_dB
# date_time_encoded
#
# the feature date_time_encoded has high importance as it leads to drastic changes in performance for 2 models!!! it needs to be removed.

# %% [markdown]
# ### Save most important features for removal in data input

# %%
# Vergleich der ersten n Features
n = 14
common_features = set(deleted_features_logreg[:n]) & set(deleted_features_rf[:n]) & set(deleted_features_xgb[:n])

# Gemeinsame Features speichern
common_features_df = pd.DataFrame(list(common_features), columns=["Common Features"])

new_entry = pd.DataFrame([["date_time_encoded"]], columns=["Common Features"])
common_features_df = pd.concat([common_features_df, new_entry], ignore_index=True)

common_features_df.to_csv("common_features.csv", index=False)

print(f"\nGemeinsame Features der ersten {n} Einträge sind:\n", common_features_df)
# Out:
# Gemeinsame Features der ersten 14 Einträge sind:
#       Common Features
# 0         band_26_dB
# 1         band_27_dB
# 2         band_28_dB
# 3             mfcc_3
# 4             mfcc_2
# 5         band_25_dB
# 6         band_29_dB
# 7  date_time_encoded
